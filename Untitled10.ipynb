# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
A=pd.read_csv("TIMETABLE.csv")

A.head(21)
# Out:
#     IDtimetable coursecode IDprogramme  coursegrps  numbstudents  stdlevel  \
# 0          3997    ENG105B         NaN        46.0           145       100
# 1          3998    ENG105B         NaN        14.0           140       100
# 2          3999    ENG105B         NaN        34.0           140       100
# 3          4000    ENG105B         NaN        35.0           140       100
# 4          4001    ENG105B         NaN        10.0           130       100
# 5          4002    ENG105B         NaN        11.0           120       100
# 6          4003    ENG105B         NaN        12.0           120       100
# 7          4004    ENG105B         NaN        13.0           120       100
# 8          4005    ENG105B         NaN        45.0           120       100
# 9          4006    ENG105B         NaN        18.0           115       100
# 10         4007    ENG105B         NaN         3.0           115       100
# ...

# %%
A.assign(Division=A["coursegrps"]/A["numbstudents"])
# Out:
#      IDtimetable coursecode           IDprogramme  coursegrps  numbstudents  \
# 0           3997    ENG105B                   NaN        46.0           145
# 1           3998    ENG105B                   NaN        14.0           140
# 2           3999    ENG105B                   NaN        34.0           140
# 3           4000    ENG105B                   NaN        35.0           140
# 4           4001    ENG105B                   NaN        10.0           130
# ..           ...        ...                   ...         ...           ...
# 770         4657     INF306    BSC ( INFO. TECH.)         NaN            32
# 771         4658     ESC399     B. ED. ( SCIENCE)         NaN            40
# 772         4659     MUD314     BACHELOR OF MUSIC         NaN             1
# 773         4660     EBS214  B. ED. ( BASIC. ED.)         NaN            16
# 774         4661     MLT215        BSC. ( MEDLAB)         NaN            63
#
# ...

# %%
A.fillna(value=10)
A
# Out:
#      IDtimetable coursecode           IDprogramme  coursegrps  numbstudents  \
# 0           3997    ENG105B                   NaN        46.0           145
# 1           3998    ENG105B                   NaN        14.0           140
# 2           3999    ENG105B                   NaN        34.0           140
# 3           4000    ENG105B                   NaN        35.0           140
# 4           4001    ENG105B                   NaN        10.0           130
# ..           ...        ...                   ...         ...           ...
# 770         4657     INF306    BSC ( INFO. TECH.)         NaN            32
# 771         4658     ESC399     B. ED. ( SCIENCE)         NaN            40
# 772         4659     MUD314     BACHELOR OF MUSIC         NaN             1
# 773         4660     EBS214  B. ED. ( BASIC. ED.)         NaN            16
# 774         4661     MLT215        BSC. ( MEDLAB)         NaN            63
#
# ...

# %%
Ba=pd.DataFrame({"A":np.random.randint(1,100,10),
                "B":np.random.randint(1,100,10),
                "C":np.random.randint(1,100,10),
                "D":np.random.randint(1,100,10),               
               "E":[np.nan,19,np.nan,10,4,5,79,3,10,100],
               })
print(Ba)
Ba.loc[1,"B"]
# Out:
#     A   B   C   D      E
# 0  91  75  74  84    NaN
# 1  30  84  92  43   19.0
# 2  82  45  93  33    NaN
# 3  96  39  40  28   10.0
# 4  12  37  71  39    4.0
# 5  96  86  48  10    5.0
# 6  18   5  19  20   79.0
# 7  39   4  88  59    3.0
# 8  48   9  31  98   10.0
# 9   8  87  86  54  100.0
# 84

# %%
B1=Ba.loc[0:5,]
B1.dropna(how="any")
pd.isna(B1)
B1.dtypes
# Out:
#     A   B   C   D     E
# 1  30  84  92  43  19.0
# 3  96  39  40  28  10.0
# 4  12  37  71  39   4.0
# 5  96  86  48  10   5.0

# %%
B1.sort_values("A", inplace=True)
B1
# Out:
# <ipython-input-11-0e1dd8b39ef9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B1.sort_values("A", inplace=True)
#     A   B   C   D     E
# 4  12  37  71  39   4.0
# 1  30  84  92  43  19.0
# 2  82  45  93  33   NaN
# 0  91  75  74  84   NaN
# 3  96  39  40  28  10.0
# 5  96  86  48  10   5.0

# %%
A[(A["coursecode"]=="ENG105B") & (A["stdlevel"]==100)  ]
# Out:
#      IDtimetable coursecode IDprogramme  coursegrps  numbstudents  stdlevel  \
# 0           3997    ENG105B         NaN        46.0           145       100
# 1           3998    ENG105B         NaN        14.0           140       100
# 2           3999    ENG105B         NaN        34.0           140       100
# 3           4000    ENG105B         NaN        35.0           140       100
# 4           4001    ENG105B         NaN        10.0           130       100
# 5           4002    ENG105B         NaN        11.0           120       100
# 6           4003    ENG105B         NaN        12.0           120       100
# 7           4004    ENG105B         NaN        13.0           120       100
# 8           4005    ENG105B         NaN        45.0           120       100
# 9           4006    ENG105B         NaN        18.0           115       100
# 10          4007    ENG105B         NaN         3.0           115       100
# ...

# %%
A[(A["coursecode"]=="ENG105B") | (A["stdlevel"]==100)  ]
# Out:
#      IDtimetable coursecode IDprogramme  coursegrps  numbstudents  stdlevel  \
# 0           3997    ENG105B         NaN        46.0           145       100
# 1           3998    ENG105B         NaN        14.0           140       100
# 2           3999    ENG105B         NaN        34.0           140       100
# 3           4000    ENG105B         NaN        35.0           140       100
# 4           4001    ENG105B         NaN        10.0           130       100
# ..           ...        ...         ...         ...           ...       ...
# 567         4172     LAR105         NaN         NaN            64       100
# 568         4173     LAR106         NaN         NaN           150       100
# 569         4174     LAR106         NaN         NaN            62       100
# 570         4175     LSB102         NaN         NaN           150       100
# 571         4176     LSB102         NaN         NaN            55       100
#
# ...
