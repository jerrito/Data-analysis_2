# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
m1=pd.read_csv("international_migration.csv")
m1
# Out:
#        year_month month_of_release     passenger_type direction citizenship  \
# 0         2020-02          2021-03  Long-term migrant  Arrivals      non-NZ
# 1         2020-09          2021-03  Long-term migrant  Arrivals      non-NZ
# 2         2020-07          2021-03  Long-term migrant  Arrivals      non-NZ
# 3         2020-07          2021-03  Long-term migrant  Arrivals      non-NZ
# 4         2020-01          2021-03  Long-term migrant  Arrivals          NZ
# ...           ...              ...                ...       ...         ...
# 401767    2018-12          2020-09  Long-term migrant  Arrivals       TOTAL
# 401768    2019-01          2020-09  Long-term migrant  Arrivals       TOTAL
# 401769    2019-02          2020-09  Long-term migrant  Arrivals       TOTAL
# 401770    2019-03          2020-09  Long-term migrant  Arrivals       TOTAL
# 401771    2019-04          2020-09  Long-term migrant  Arrivals       TOTAL
#
# ...

# %%
m1.columns
print(m1.describe(include="all"))
 #m1["passenger_type","country_of_residence"]
m1.head(n=80)
# Out:
# <ipython-input-35-f422ad36399e>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(m1.describe(include="all"))
# <ipython-input-35-f422ad36399e>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(m1.describe(include="all"))
#                  year_month     month_of_release     passenger_type direction  \
# count                401772               401772             401772    401772
# unique                  243                    7                  1         1
# top     2020-01-01 00:00:00  2020-09-01 00:00:00  Long-term migrant  Arrivals
# ...

# %%
m1.loc[:"passenger_type","country_of_residence"]
# Out:
# 0         Andorra
# 1         Andorra
# 2         Andorra
# 3         Andorra
# 4         Andorra
#            ...
# 401767      TOTAL
# 401768      TOTAL
# 401769      TOTAL
# 401770      TOTAL
# 401771      TOTAL
# Name: country_of_residence, Length: 401772, dtype: object

# %%
m1.iloc[5:20,1:4]
# Out:
#    month_of_release     passenger_type direction
# 5           2021-03  Long-term migrant  Arrivals
# 6           2021-03  Long-term migrant  Arrivals
# 7           2021-03  Long-term migrant  Arrivals
# 8           2021-03  Long-term migrant  Arrivals
# 9           2021-03  Long-term migrant  Arrivals
# 10          2021-03  Long-term migrant  Arrivals
# 11          2021-03  Long-term migrant  Arrivals
# 12          2021-03  Long-term migrant  Arrivals
# 13          2021-03  Long-term migrant  Arrivals
# 14          2021-03  Long-term migrant  Arrivals
# 15          2021-03  Long-term migrant  Arrivals
# 16          2021-03  Long-term migrant  Arrivals
# 17          2021-03  Long-term migrant  Arrivals
# 18          2021-03  Long-term migrant  Arrivals
# 19          2021-03  Long-term migrant  Arrivals

# %%
print(m1.dtypes)
m1["month_of_release"]=pd.to_datetime(m1["month_of_release"])
m1["year_month"]=pd.to_datetime(m1["year_month"])
# Out:
# year_month              datetime64[ns]
# month_of_release        datetime64[ns]
# passenger_type                  object
# direction                       object
# citizenship                     object
# visa                            object
# country_of_residence            object
# estimate                         int64
# standard_error                   int64
# status                          object
# dtype: object

# %%
m1.dtypes
# Out:
# year_month              datetime64[ns]
# month_of_release        datetime64[ns]
# passenger_type                  object
# direction                       object
# citizenship                     object
# visa                            object
# country_of_residence            object
# estimate                         int64
# standard_error                   int64
# status                          object
# dtype: object

# %%
m1.head(n=21)
# Out:
#    year_month month_of_release     passenger_type direction citizenship  \
# 0  2020-02-01       2021-03-01  Long-term migrant  Arrivals      non-NZ
# 1  2020-09-01       2021-03-01  Long-term migrant  Arrivals      non-NZ
# 2  2020-07-01       2021-03-01  Long-term migrant  Arrivals      non-NZ
# 3  2020-07-01       2021-03-01  Long-term migrant  Arrivals      non-NZ
# 4  2020-01-01       2021-03-01  Long-term migrant  Arrivals          NZ
# 5  2020-02-01       2021-03-01  Long-term migrant  Arrivals          NZ
# 6  2020-09-01       2021-03-01  Long-term migrant  Arrivals          NZ
# 7  2020-12-01       2021-03-01  Long-term migrant  Arrivals          NZ
# 8  2021-01-01       2021-03-01  Long-term migrant  Arrivals      non-NZ
# 9  2019-11-01       2021-03-01  Long-term migrant  Arrivals      non-NZ
# 10 2019-12-01       2021-03-01  Long-term migrant  Arrivals      non-NZ
# 11 2020-01-01       2021-03-01  Long-term migrant  Arrivals      non-NZ
# ...

# %%
m2=m1.loc[m1["estimate"]>20, ["estimate","visa"]]
m2.head(10)
# Out:
#     estimate      visa
# 11        23  Resident
# 16        23  Resident
# 27        25   Student
# 28        50   Student
# 33        39   Visitor
# 34        26   Visitor
# 35        30   Visitor
# 48        50      Work
# 49        44      Work
# 50        51      Work
