# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
l=pd.read_csv("MCUD.csv")
l.info();
time=pd.read_csv("TIMETABLE.csv")

print(time.info())
time.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Period                  80 non-null     int64
#  1   Male_or_Female          80 non-null     object
#  2   Status_before_Marriage  80 non-null     object
#  3   Median_Age_at_Marriage  80 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   IDtimetable   775 non-null    int64
#  1   coursecode    775 non-null    object
#  2   IDprogramme   649 non-null    object
#  3   coursegrps    59 non-null     float64
#  4   numbstudents  775 non-null    int64
#  5   stdlevel      775 non-null    int64
#  6   IDroom        775 non-null    int64
# ...

# %%
time.head(30)
#time.tail(30)
# Out:
#     IDtimetable coursecode IDprogramme  coursegrps  numbstudents  stdlevel  \
# 0          3997    ENG105B         NaN        46.0           145       100
# 1          3998    ENG105B         NaN        14.0           140       100
# 2          3999    ENG105B         NaN        34.0           140       100
# 3          4000    ENG105B         NaN        35.0           140       100
# 4          4001    ENG105B         NaN        10.0           130       100
# 5          4002    ENG105B         NaN        11.0           120       100
# 6          4003    ENG105B         NaN        12.0           120       100
# 7          4004    ENG105B         NaN        13.0           120       100
# 8          4005    ENG105B         NaN        45.0           120       100
# 9          4006    ENG105B         NaN        18.0           115       100
# 10         4007    ENG105B         NaN         3.0           115       100
# ...

# %%
print(time.columns)
T1=time.groupby(["numbstudents","stdlevel","coursecode"]).agg({"numbstudents":"mean","coursegrps":"mean","IDroom":"min",})
T1.tail(50)
# Out:
# Index(['IDtimetable', 'coursecode', 'IDprogramme', 'coursegrps',
#        'numbstudents', 'stdlevel', 'IDroom', 'roomname', 'examPERIOD',
#        'examDATE'],
#       dtype='object')
#                                   numbstudents  coursegrps  IDroom
# numbstudents stdlevel coursecode
# 161          400      BPS426               161         NaN      33
# 168          200      BPS221               168         NaN      47
#                       BPS222               168         NaN      35
#                       BPS224               168         NaN      32
# 169          200      BPS225               169         NaN      35
# 179          300      NUR307               179         NaN      48
#                       NUR311               179         NaN      32
#                       NUR315               179         NaN      33
#                       NUR322               179         NaN      32
#                       NUR324               179         NaN      32
# ...

# %%
T1.sort_values((by="IDtimetable"), ascending 'coursecode', 'IDprogramme')
